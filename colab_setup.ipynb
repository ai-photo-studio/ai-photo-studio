# %% [markdown]
# # AI Photo Studio Colab Setup
#
# Reproducible validation flow for the local AI stack on Colab.

# %%
# %cd /content/ai-photo-studio-whatsapp
# !bash colab_setup.sh

# %%
import torch
print('cuda_available=', torch.cuda.is_available())
if torch.cuda.is_available():
    print('cuda_device=', torch.cuda.get_device_name(0))
    print('cuda_version=', torch.version.cuda)

# %%
import rembg
import ultralytics
import open_clip
import realesrgan
print('imports ok')

# %%
from pathlib import Path

path = Path('scripts/validation-output.json')
print(path.read_text()) if path.exists() else print('validation output missing')
